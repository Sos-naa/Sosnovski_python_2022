# %% [markdown]
# # Задание 2.
#
# **NB. Все упражнения ниже нужно делать без использования циклов Python в явном (`while`, `for`) и неявном виде (list comprehension, `map`, `reduce` и пр)**
#
# Задания по манипуляциям с массивами чаще всего решаются в одно/два выражения.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

A = np.random.randint(0, 100, size=(200, 50))
A
# Out:
# array([[67,  3, 68, ..., 71, 19, 34],
#        [30, 96, 20, ...,  4, 96, 28],
#        [14, 81, 38, ..., 82, 44, 85],
#        ...,
#        [87, 15, 20, ..., 85, 42, 73],
#        [55, 21, 20, ..., 67, 40, 13],
#        [ 5, 14, 74, ..., 51, 97, 42]])

# %% [markdown]
# # Задание 2.1 (2 балла)
#
# Сгенерируйте новый массив, в котором столбцы массива `A` переставлены в случайном порядке

# %%
import numpy as np


arr = np.random.randint (0, 100, (5, 5)) # Создаем массив 5x5 заполненный случайными целыми числами от 0 до 100
print (arr)
arr = np.random.permutation(arr.T).T # Перемешиваем столбцы нашего массива в случайном порядке
print (arr)                          # Если оставить только: np.random.permutation(arr) то перемешаются строки
# Out:
# [[70 49 78 55 43]
#  [12 11 37 65 49]
#  [25 57  7 56 54]
#  [60 17 58  9 38]
#  [12 63 67 56 68]]
# [[55 70 78 43 49]
#  [65 12 37 49 11]
#  [56 25  7 54 57]
#  [ 9 60 58 38 17]
#  [56 12 67 68 63]]

# %% [markdown]
# # Задание 2.2 (5 баллов)
#
# Сгенерируйте новый массив, который содержит только те строки массива `A`, в которых:
# - сумма элементов по четным столбцам (индексы $0, 2, \ldots$) больше среднего значения (по всему массиву) суммы элементов по нечетным столбцам (индексы $1, 3, \ldots$)

# %%
import numpy as np

arr = np.random.randint (0, 10, (5, 6)) # Создаем массив 5x6 заполненный случайными целыми числами от 0 до 10
print (arr)


print("--------")

arr1 = arr[0::1, ::2] # Вытаскиваем четные столбцы
print ("Четные столбцы:\n",arr1)


print("--------")

arr2 = arr[0::1, 1::2] # Вытаскиваем нечетные столбцы
print ("Нечетные столбцы:\n",arr2)


print("--------")

arr11 = arr1.sum(axis=1) # Сумма четных столбцов в одной строке для проверки
print("Сумма четных столбцов:\n",arr11)


print("--------")

arr21 = arr2.sum(axis=1) # Сумма нечетных столбцов в одной строке для проверки
print("Сумма нечетных столбцов:\n",arr21)


print("--------")

aRR = arr[arr1.sum(axis=1) > arr2.sum(axis=1)] # Получаем подматрицу, где остаются только те строки, 
                                               # в которых сумма четных элементов превышает сумму нечетных элементов
print("Искомые строки:\n",aRR)
# Out:
# [[4 0 3 3 6 8]
#  [9 5 0 6 1 8]
#  [5 1 2 2 3 2]
#  [5 3 0 2 6 9]
#  [5 7 1 8 3 6]]
# --------
# Четные столбцы:
#  [[4 3 6]
#  [9 0 1]
#  [5 2 3]
#  [5 0 6]
#  [5 1 3]]
# --------
# Нечетные столбцы:
#  [[0 3 8]
#  [5 6 8]
#  [1 2 2]
#  [3 2 9]
#  [7 8 6]]
# --------
# Сумма четных столбцов:
#  [13 10 10 11  9]
# --------
# Сумма нечетных столбцов:
#  [11 19  5 14 21]
# --------
# Искомые строки:
#  [[4 0 3 3 6 8]
#  [5 1 2 2 3 2]]

# %% [markdown]
# # Задача 2.3 (3 балла)
#
# Найдите индекс строки массива `A`, в которой разница между максимальным и минимальным элементом максимальна

# %%
import pandas as pd

arr = np.random.randint (0, 10, (5, 6)) # Создаем массив 5x6 заполненный случайными целыми числами от 0 до 10
print (arr)
print("--------")



maxarr = arr.max(axis=1) # Находим максимальные элементы строк
minarr = arr.min(axis=1) # Находим минимальные элементы строк

print(maxarr)
print("--------")

print(minarr)
print("--------")

Q = (maxarr - minarr).argmax() # argmax выводит только первое максимальное значение даже если их несколько
print(Q)
print("--------")


    # Так же можно попробовать сделать через библиотеку pandas
    # Если выше убрать .argmax() из Q = (maxarr - minarr).argmax()

#frame1 = pd.DataFrame(Q)
#print (frame1)
#print("--------")

#D = frame1.idxmax() # idxmax выводит только первое максимальное значение даже если их несколько
#print(D)
# Out:
# [[6 0 8 7 8 5]
#  [0 0 9 6 5 9]
#  [5 6 4 5 7 4]
#  [6 4 0 1 0 1]
#  [6 9 0 4 7 3]]
# --------
# [8 9 7 6 9]
# --------
# [0 0 4 0 0]
# --------
# 1
# --------

# %% [markdown]
# # Задание 2.4 (7 баллов)
#
# Сгенерируйте массив той же размерности, что и `A`, но в котором каждый элемент заменен на его порядковый номер (начиная с 1) в отсортированном по возрастанию массиве из элементов `A`
#
# Если `A` выглядит так:
# $$
# \begin{pmatrix}
# 12 & 14\\
# 1 & 2
# \end{pmatrix}
# $$
# то результат должен быть
# $$
# \begin{pmatrix}
# 3 & 4\\
# 1 & 2
# \end{pmatrix}
# $$
#
# *Tip: рассмотрите возможность неоднократного применения [argsort()](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.argsort.html)*

# %%
import numpy as np

arr = np.random.randint (0, 100, (3, 3)) # Создаем массив 3x3 заполненный случайными целыми числами от 0 до 10
print (arr)                             # Для более удобного просмотра результатов
print("--------")

ind = np.argsort(np.argsort(arr, axis=None)) + 1
print(ind)

G = ind.reshape(3,3) # Для удобства можно заранее задать переменные с размерностью массива

print("--------")
print(G)
# Out:
# [[59 95 23]
#  [96 57 22]
#  [35 71 15]]
# --------
# [6 8 3 9 5 2 4 7 1]
# --------
# [[6 8 3]
#  [9 5 2]
#  [4 7 1]]

# %% [markdown]
# # Задание 2.5 (2 балла)
#
# Примените $\min-\max$ - нормализацию к строкам массива `A`. То есть нужно получить новый массивы, в каждой строке которого максимальный элементы равен $1$, минимальный - $0$.

# %%
arr = np.random.randint (0, 10, (5, 5)) # Создаем массив 5x6 заполненный случайными целыми числами от 0 до 10
print (arr)
print("--------")

G = np.transpose((arr.T - np.min(arr, axis=1)) / (np.max(arr, axis=1) - np.min(arr, axis=1)))
print(G)
# Out:
# [[7 5 5 2 8]
#  [3 3 5 9 1]
#  [1 0 6 6 8]
#  [5 1 2 2 8]
#  [0 2 5 7 4]]
# --------
# [[0.83333333 0.5        0.5        0.         1.        ]
#  [0.25       0.25       0.5        1.         0.        ]
#  [0.125      0.         0.75       0.75       1.        ]
#  [0.57142857 0.         0.14285714 0.14285714 1.        ]
#  [0.         0.28571429 0.71428571 1.         0.57142857]]

# %% [markdown]
# # Задание 2.6 (2 балла)
#
# Сгенерируйте новый трехмерный массив, размерности $10 \times 200 \times 50$. Подмассивы по нулевой оси должны состоять из элементов `A`, умноженных на $1 - 10$ соответственно

# %%
arr = np.random.randint (0, 10, (10, 200, 50)) # Создаем трехмерный массив
print (arr)
print("--------")

np.concatenate((arr, arr*2, arr*3, arr*4, arr*5, arr*6, arr*7, arr*8, arr*9, arr*10)).reshape(10, arr.shape[2], arr.shape[1], arr.shape[0])
# Out:
# [[[7 1 0 ... 8 9 4]
#   [5 6 5 ... 1 9 9]
#   [5 7 9 ... 1 9 6]
#   ...
#   [2 8 0 ... 6 1 8]
#   [2 0 8 ... 7 5 3]
#   [5 3 9 ... 2 8 3]]
#
#  [[3 2 4 ... 4 6 3]
#   [6 2 6 ... 7 6 9]
#   [8 6 7 ... 6 7 1]
#   ...
#   [1 3 7 ... 8 6 6]
#   [5 9 4 ... 2 8 9]
#   [4 7 2 ... 4 1 0]]
#
#  [[1 5 9 ... 6 2 9]
#   [1 6 7 ... 0 6 0]
#   [0 2 0 ... 5 3 9]
#   ...
#   [9 9 7 ... 6 4 4]
#   [3 2 5 ... 0 1 0]
#   [8 4 8 ... 8 7 4]]
#
#  ...
#
#  [[0 4 5 ... 2 1 2]
#   [3 1 4 ... 9 5 7]
#   [2 1 6 ... 0 7 3]
#   ...
#   [7 4 0 ... 4 4 0]
#   [2 9 4 ... 4 5 1]
#   [2 3 1 ... 9 3 0]]
#
#  [[2 8 7 ... 2 9 6]
#   [2 7 2 ... 0 2 2]
#   [4 5 4 ... 7 0 2]
#   ...
#   [7 6 7 ... 1 2 6]
#   [0 7 7 ... 8 4 4]
#   [1 6 6 ... 1 2 3]]
#
#  [[3 4 7 ... 3 9 2]
#   [4 7 8 ... 6 4 4]
#   [0 1 8 ... 9 3 8]
#   ...
#   [6 5 3 ... 7 9 2]
#   [1 5 8 ... 3 2 0]
#   [0 5 3 ... 6 1 9]]]
# --------
# array([[[[ 7,  1,  0, ...,  0,  8,  1],
#          [ 5,  8,  6, ...,  3,  3,  5],
# ...

# %% [markdown]
# # Задание 2.7 (2 балла)
#
# Создайте новый массив, такой же размерности, как и `A`, в котором сначала сгруппированы четные столбцы `A`, потом  нечетные. Используйте [np.concat()](https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html)

# %%
arr = np.random.randint (0, 10, (5, 5)) # Создаем массив 5x5 заполненный случайными целыми числами от 0 до 10
print (arr)
print("--------")

H = np.concatenate((arr[:, ::2], arr[:, 1::2]), axis=1) # Отделяем четные столбцы от нечетных и группируем
print(H)                                                # сначала все четные, после нечетные
# Out:
# [[7 4 2 0 8]
#  [7 2 9 8 2]
#  [4 2 5 5 4]
#  [2 0 9 5 0]
#  [5 1 6 6 1]]
# --------
# [[7 2 8 4 0]
#  [7 9 2 2 8]
#  [4 5 4 2 5]
#  [2 9 0 0 5]
#  [5 6 1 1 6]]

# %% [markdown]
# # Задание 2.8 (2 балла)
#
# Посчитайте количество строк массива `A`, в который все элементы больше 5. Используйте [np.all()](https://numpy.org/doc/stable/reference/generated/numpy.all.html)

# %%
arr = np.random.randint (4, 10, (5, 5)) # Создаем массив 5x5 заполненный случайными целыми числами от 4 до 10
print (arr)                             # для того чтобы увеличить шансы появления строки в которой все элементы больше 5
print("--------")

G = np.all(arr> 5, axis = 1).sum() # Проверяем в каких строках все значения больше 5 и ищем их сумму (если такие есть)
print(G)
# Out:
# [[5 6 5 6 9]
#  [6 5 8 7 6]
#  [7 7 9 8 6]
#  [8 6 8 6 9]
#  [9 7 9 5 5]]
# --------
# 2

# %% [markdown]
# # Задание 2.9 (2 балла)
#
# Поделите массив `A` горизонтально на 10 частей и создайте новый массив размерности $20 \times 50$, который является средним этих частей. Используйте [np.split()](https://numpy.org/doc/stable/reference/generated/numpy.split.html)

# %%
arr = np.random.randint (1, 100, (200, 50)) # Создаем массив 200x50 заполненный случайными целыми числами от 1 до 100
print (arr)                            
print("--------")

G = np.mean(np.array(np.split(arr, 10)), axis = 0)
print (G)
# Out:
# [[15  6 84 ... 30 90 95]
#  [58 87 53 ... 32 69  1]
#  [95 47 66 ...  1 11 41]
#  ...
#  [56 80 80 ... 96 55  8]
#  [76 92 63 ... 81 56 12]
#  [83 66  2 ...  5 11 13]]
# --------
# [[53.9 54.9 71.1 49.1 53.6 42.9 50.5 43.2 51.9 43.8 44.5 58.6 44.3 42.1
#   50.8 54.4 51.4 41.4 64.7 61.7 47.1 40.1 58.7 68.5 61.3 54.8 44.1 59.2
#   44.4 45.1 59.3 58.1 50.1 64.2 67.1 51.1 55.9 56.8 58.8 61.4 46.9 44.9
#   68.6 52.4 44.3 50.6 26.8 55.5 56.7 62.5]
#  [57.2 61.6 56.3 56.7 42.4 54.3 29.6 48.  49.1 44.2 43.3 53.6 43.4 45.6
#   51.9 43.3 35.2 42.2 35.5 54.7 45.6 41.2 44.6 45.8 60.2 52.  53.6 47.2
#   35.3 63.9 45.  47.9 54.7 74.8 56.  43.3 46.7 46.3 63.9 61.2 33.  36.6
#   42.6 57.9 55.3 51.2 30.8 56.7 52.9 42.1]
#  [51.3 47.  61.1 56.7 50.2 67.3 38.1 44.  43.6 60.1 42.2 61.2 41.5 59.
#   48.3 60.8 50.4 54.2 58.1 72.1 44.3 44.6 53.4 57.9 47.3 46.6 27.4 46.7
#   46.8 56.  43.8 72.  41.1 64.3 69.1 50.8 55.2 48.9 38.6 47.5 41.3 27.
#   51.7 62.2 52.  57.3 48.9 26.5 57.5 49.6]
# ...

# %% [markdown]
# # Задание 2.10 (4 балла)
#
# "Разверните" массив `A` в одномерный массив. Оставьте в нём только уникальные элементы в том же порядке, в котором они встречаются в массиве. Используйте [np.unique()](https://numpy.org/doc/stable/reference/generated/numpy.unique.html)

# %%
arr = np.random.randint (1, 20, (10, 10)) # Создаем массив 10x10 заполненный случайными целыми числами от 1 до 20
print (arr)                               # так будет удобнее проверять результат
print("--------")


uniq, index = np.unique(arr.reshape(1, arr.shape[0]*arr.shape[1]), return_index=True)
uniq[index.argsort()]
# Out:
# [[19 14  3  6  7  7 10  4 10 10]
#  [ 2  1 16  2  1  9 12  4 13 17]
#  [18 17 11 10 18 17 19  2  8  9]
#  [18 18  8  2  3 19  5  2 18  4]
#  [ 9 18  2  6 19 10  8 17 16  1]
#  [ 9 14  6  1 18  6  7  5  4  3]
#  [15 14 13  6  7  3 14 17  6  1]
#  [16  9  4  5  5  7  6 11  7  7]
#  [18 11 19  9 11 15  8 18 16  1]
#  [ 6 10  7  5  3 10  2  4 12 12]]
# --------
# array([19, 14,  3,  6,  7, 10,  4,  2,  1, 16,  9, 12, 13, 17, 18, 11,  8,
#         5, 15])

# %% [markdown]
# # Задание 2.11 (3 балла)
#
# Создайте одномерный массив размерности $200$, в котором каждый элемент - евклидово расстояние между соответствующей строкой `A` и "средней" строкой `A`

# %% [markdown]
# # Задание 2.12 (2 балла)
#
# Создайте новый массив, который состоит из элементов `A`, измененных по следующим правилам:
# - если элемент меньше $50$, то он умножается на $2$
# - в противном случае он умножается на $3$
#
# Используйте [np.where()](https://numpy.org/doc/stable/reference/generated/numpy.where.html)

# %%
arr = np.random.randint (1, 100, (10, 10)) # Создаем массив 10x10 заполненный случайными целыми числами от 1 до 100
print (arr)                               
print("--------")


G = np.where(arr<50, arr*2, arr*3)
print(G)
# Out:
# [[90 96 16 26 20 91 76 28 97 82]
#  [17 72 53 20 18 67 13 27 61 45]
#  [98 25 28 73  5 74 26 14 59 71]
#  [36 84 25 24 15 29 28 76 55 56]
#  [84 68  9 47 54 21 14  4 33 78]
#  [50  9 11 75 71 41 84 51 29 93]
#  [26 99 29 86 38 21 10  6 79 31]
#  [56  4 35 88 46 89 50 82 92 61]
#  [31 24 21 59 78 13 73 34 14 31]
#  [20 48 53 70 35 13 76 48 13 92]]
# --------
# [[270 288  32  52  40 273 228  56 291 246]
#  [ 34 216 159  40  36 201  26  54 183  90]
#  [294  50  56 219  10 222  52  28 177 213]
#  [ 72 252  50  48  30  58  56 228 165 168]
#  [252 204  18  94 162  42  28   8  66 234]
#  [150  18  22 225 213  82 252 153  58 279]
#  [ 52 297  58 258  76  42  20  12 237  62]
#  [168   8  70 264  92 267 150 246 276 183]
#  [ 62  48  42 177 234  26 219  68  28  62]
#  [ 40  96 159 210  70  26 228  96  26 276]]

# %% [markdown]
# # Задание 2.13 (7 баллов)
#
# Разверните массив `A` в одномерный массив. Создайте три новых массива, подсчитав скользящие средние по окнам $3$, $5$, $10$. Найдите сумму этих массивов, выровнив из размерности нулями справа
#
# *Tip: реализуйте функцию, которая считает скользящее среднее. Используйте [np.cumsum()](https://numpy.org/doc/stable/reference/generated/numpy.cumsum.html) или [np.convolve()](https://numpy.org/doc/stable/reference/generated/numpy.convolve.html)*

# %%
arr = np.random.randint (1, 100, (4, 4)) # Создаем массив 4x4 заполненный случайными целыми числами от 1 до 100
print (arr)                               
print("--------")

def moving_avg(x, n):
    cumsum = np.cumsum(np.insert(x, 0, 0))
    return ((cumsum[n:] - cumsum[:-n]) / float(n))

arr1 = arr.reshape(1, arr.shape[0]*arr.shape[1])[0]

arr3 = moving_avg(arr1, 3) #Скользящее среднее по 3 окну
print (arr3)
print("--------")
arr5 = moving_avg(arr1, 5) #Скользящее среднее по 5 окну
print (arr5)
print("--------")
arr10 = moving_avg(arr1, 10) #Скользящее среднее по 10 окну
print (arr10)
print("--------")
arr3 = np.pad(arr3, (0, arr1.shape[0] - arr3.shape[0]), 'constant') #Выравниваем
print (arr3)
print("--------")
arr5 = np.pad(arr5, (0, arr1.shape[0] - arr5.shape[0]), 'constant') #Выравниваем
print (arr5)
print("--------")
arr10 = np.pad(arr10, (0, arr1.shape[0] - arr10.shape[0]), 'constant') #Выравниваем
print (arr10)
print("--------")
arrsum = arr3 + arr5 + arr10
print(arrsum)
# Out:
# [[69 66 42  4]
#  [ 1 20 73 92]
#  [ 7 89 22 29]
#  [31 14 49 26]]
# --------
# [59.         37.33333333 15.66666667  8.33333333 31.33333333 61.66666667
#  57.33333333 62.66666667 39.33333333 46.66666667 27.33333333 24.66666667
#  31.33333333 29.66666667]
# --------
# [36.4 26.6 28.  38.  38.6 56.2 56.6 47.8 35.6 37.  29.  29.8]
# --------
# [46.3 41.6 37.9 36.8 37.8 42.6 43.2]
# --------
# [59.         37.33333333 15.66666667  8.33333333 31.33333333 61.66666667
#  57.33333333 62.66666667 39.33333333 46.66666667 27.33333333 24.66666667
#  31.33333333 29.66666667  0.          0.        ]
# --------
# [36.4 26.6 28.  38.  38.6 56.2 56.6 47.8 35.6 37.  29.  29.8  0.   0.
#   0.   0. ]
# --------
# [46.3 41.6 37.9 36.8 37.8 42.6 43.2  0.   0.   0.   0.   0.   0.   0.
#   0.   0. ]
# --------
# [141.7        105.53333333  81.56666667  83.13333333 107.73333333
#  160.46666667 157.13333333 110.46666667  74.93333333  83.66666667
#   56.33333333  54.46666667  31.33333333  29.66666667   0.
# ...

# %% [markdown]
# # Задание 2.14 (8 баллов)
#
# Постройте график функции $$f(x) = (5  \sin(2x) - \cos^2(x) - 1 + |x^3| - x^2) / (x^2 + 1)$$
#
# и производной от этой функции.  Найдите минимум с помощью `scipy` и обозначьте его на графике. На этой же оси постройте графики скользящего среднего этой функции с окном $1$, $2$, $5$.

# %%
import matplotlib.pyplot as plt
from scipy.misc import derivative
from scipy.optimize import fmin

def f(x):
    return (5 * np.sin(2*x) - np.cos(x)**2 - 1 + abs(x**3) - x**2) / (x**2 + 1) # Функция 


x = np.arange(-10, 10, 0.1) # Генерируем значения от -10 до 10 с интервалом 0.1
y = f(x)
diff = derivative(f, x, dx=1e-6)
f_min = fmin(f, np.array([0]))

f1 = moving_avg(y, 1) #Скользящее среднее по 1 окну
f2 = moving_avg(y, 2) #Скользящее среднее по 2 окну
f3 = moving_avg(y, 5) #Скользящее среднее по 5 окну

fig, ax = plt.subplots()

ax.plot(x, y, linestyle = '-', linewidth = 2, color = 'green')

ax.plot(x, diff, linestyle = '-', linewidth = 2, color = 'red')

ax.plot(x, f1, linestyle = '--', linewidth = 1.5, color = 'black')

ax.plot(x[1:], f2, linestyle = '--', linewidth = 1, color = 'yellow')

ax.plot(x[4:], f3, linestyle = '--', linewidth = 1, color = 'pink')

ax.plot(f_min, f(f_min),'ro')
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -4.882074
#          Iterations: 23
#          Function evaluations: 46

# %% [markdown]
# # Задание 2.15 (10 баллов)
#
# Есть следующий алгоритм семплинирования, на вход функции подается вектор из целых положительных чисел и число семплов.

# %%
from typing import List 

def sample(x: List[int], c: int) -> List[int]:
    assert len(x) > 0
    
    s = np.sum(x)
    res = []
    for _ in range(c):
        val = s * np.random.random()
        cur, idx = 0, 0        
        while cur + x[idx] <= val:
            cur += x[idx]
            idx += 1
            
        res.append(idx)
    return res

            
sample([50, 3, 1, 7, 20], 5)
# Out:
# [0, 4, 4, 0, 0]

# %% [markdown]
# Реализуйте данный алгоритм более оптимальным способом на массивах `numpy`, без использования циклов. Проверьте корректность и идентичность алгоритмов семплирования с помощью статистических тестов.

# %% [markdown]
# # Задание 2.16 (5 баллов)
#
# Есть следующий алгоритм "случайного блуждания"

# %%
import random 

def walk(n: int):
    cur_position = 0
    for i in range(n):
        cur_position += random.choice([-3, -1, 0, 2, 3])

    return cur_position

walk(10_000)
# Out:
# 2003

# %% [markdown]
# Реализуйте более эффективную версию с помощью `numpy`, сравните производительность (используя, например, magic `timeit`). Воспользовавшись [kdeplot()](https://seaborn.pydata.org/generated/seaborn.kdeplot.html) или аналогами, постройте график распределения значений `walk(10_000)` на каком-то разумном числе запусков.

# %% [markdown]
# # Задание 2.17 (5 баллов)
#
# Имеется функция, которая проделывает достаточно странные манипуляции с массивом `numpy`

# %%
import numpy.typing as npt

def strange_conv(a: npt.NDArray[np.float64]) -> np.float64:
    x = a.shape[0]
    y = a.shape[1]

    t = 1.
    for y in range(y - 5):
        for x in range(x - 3):
            c = 1.5 * a[y+1, x+2] - a[y+5, x+3] * a[y, x] + 0.2 * a[y+4, x]
            t = 0.2 * t + 0.8 * c

    return t


a = np.random.random((10000, 10000))
strange_conv(a)
# Out:
# -0.13580565475012618

# %% [markdown]
# Оптимизируйте данную функцию с помощью (2 на выбор):
# - [Numba](https://numba.pydata.org)
# - `Cython` (+5 баллов)
# - [Taichi](https://github.com/taichi-dev/taichi) (+5 баллов)
# - `Pythran `[[1]](https://pythran.readthedocs.io/en/latest/), [[2]](https://serge-sans-paille.github.io/pythran-stories/pythran-tutorial.html) (+2 балла)
#
# Сравните производительность.
